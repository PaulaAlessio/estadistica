# %%
import matplotlib.pyplot as plt
import pandas as pd 
df = pd.DataFrame([3]*6 + [4]*25 + 34*[5] + 42*[6] + 50*[7] + 27*[8] + 13*[9] + 3*[10])
df.boxplot()
# Out:
# <Axes: >

# %%
all_marks = pd.read_csv("calificaciones_asignaturas.csv")
all_marks.head()
# Out:
#               Name Gender  Math  Physics  Chemistry
# 0         John Doe      M    85       78         90
# 1       Jane Smith      F    92       88         94
# 2  Michael Johnson      M    78       82         80
# 3      Emily Brown      F    90       85         88
# 4  Daniel Martinez      M    75       80         77

# %%
all_marks.columns
# Out:
# Index(['Name', 'Gender', 'Math', 'Physics', 'Chemistry'], dtype='object')

# %%
plt.boxplot(all_marks.loc[:, ['Math', 'Physics', 'Chemistry']]);
plt.show()

# %%
fmarks=all_marks.loc[all_marks['Gender']=='F']
plt.boxplot(fmarks.loc[:,['Math', 'Physics', 'Chemistry']])
plt.show()

# %%
mmarks=all_marks.loc[all_marks['Gender']=='M']
plt.boxplot(mmarks.loc[:,['Math', 'Physics', 'Chemistry']])
plt.show()

# %%
mmarks.boxplot(column=['Math', 'Physics', 'Chemistry'])
# Out:
# <Axes: >
